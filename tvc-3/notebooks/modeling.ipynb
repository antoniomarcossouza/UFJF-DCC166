# %% [markdown]
# # Modelagem - Validação Acadêmica
#
# Demonstração dos resultados do pipeline offline (sem treinamento neste notebook).

# %%
import json
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / "src"))

from utils.paths import MODELS_DIR, REPORTS_DIR

summary_path = MODELS_DIR / "training_summary.json"
if summary_path.exists():
    summary = json.loads(summary_path.read_text())
    print("Melhor modelo:", summary.get("best_model"))
    print("Métricas:", summary.get("metrics"))
else:
    print("Execute: make pipeline")

feature_report = REPORTS_DIR / "feature_selection.json"
if feature_report.exists():
    report = json.loads(feature_report.read_text())
    print("Features selecionadas:", len(report.get("selected_features", [])))
