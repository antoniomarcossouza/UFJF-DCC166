# %% [markdown]
# # Exploração - CIC-IoT-2023
#
# Notebook de **exploração e validação**. Toda lógica reutilizável está em `src/`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / "src"))

import pandas as pd

from utils.config import load_config
from utils.paths import PROCESSED_DATA_DIR

config = load_config()
dataset_path = PROCESSED_DATA_DIR / "dataset.parquet"
if dataset_path.exists():
    df = pd.read_parquet(dataset_path)
    display(df.head())
    display(df["label_binary"].value_counts())
else:
    print("Execute o pipeline offline: make prepare")
